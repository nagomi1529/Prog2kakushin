# %% [markdown]
# <a href="https://colab.research.google.com/github/nagomi1529/Prog2kakushin/blob/main/work3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 画像処理

# %% [markdown]
# 読み込んだ画像の背景を取り除くプログラム

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # !pip install rembg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 54.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.2 MB/s eta 0:00:00
# ...

# %%
import cv2, sys
from google.colab.patches import cv2_imshow
from rembg import remove
from PIL import Image

import glob

def removal(img):
  input_path = img
  output_path = f'{img}.png'

  input = Image.open(input_path)
  output = remove(input)
  output.save(output_path)

  img2 = cv2.imread(f'{img}.png')
  cv2_imshow(img2)

file_list = glob.glob('**/*.png',recursive=True)

for file in file_list:
  removal(file)
# Out:
# <PIL.Image.Image image mode=RGB size=320x214>
# <PIL.Image.Image image mode=RGB size=320x214>
# <PIL.Image.Image image mode=RGB size=320x214>
# <PIL.Image.Image image mode=RGB size=320x214>
