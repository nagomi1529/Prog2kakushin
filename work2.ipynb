# %% [markdown]
# <a href="https://colab.research.google.com/github/nagomi1529/Prog2kakushin/blob/main/work2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2, sys
from google.colab.patches import cv2_imshow

img = cv2.imread('drive/MyDrive/ichidai.jpg')
if img is None:
  sys.exit('エラー: ファイルを開けませんでした')

r = 0
g = 0
b = 0
h = img.shape[0]
w = img.shape[1]
array = np.zeros((3,h,w))
for iy in range(h):
  for ix in range(w):
    r += img[iy,ix][2]
    g += img[iy,ix][1]
    b += img[iy,ix][0]
    array[2][iy][ix] = r
    array[1][iy][ix] = g
    array[0][iy][ix] = b

img2 = np.zeros((w,h,3),np.uint8)
h2 = img2.shape[0]
w2 = img2.shape[1]
for iy2 in range(h2):
  for ix2 in range(w2):
    img2[iy2,ix2][2] = array[2][ix2][iy2]
    img2[iy2,ix2][1] = array[1][ix2][iy2]
    img2[iy2,ix2][0] = array[0][ix2][iy2]

cv2_imshow(img)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=320x214>
# <PIL.Image.Image image mode=RGB size=214x320>
